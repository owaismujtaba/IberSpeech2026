# %%
import mne

# %%
epochs = mne.read_epochs('/home/owaismujtaba/projects/IberSpeech2026/processed/words/sub-01_ses-1.fif')
# Out:
# Reading /home/owaismujtaba/projects/IberSpeech2026/processed/words/sub-01_ses-1.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 510 matching events found
# No baseline correction applied
# 0 projection items activated
# /tmp/ipykernel_287069/1433773509.py:1: RuntimeWarning: This filename (/home/owaismujtaba/projects/IberSpeech2026/processed/words/sub-01_ses-1.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs('/home/owaismujtaba/projects/IberSpeech2026/processed/words/sub-01_ses-1.fif')

# %%
epochs
# Out:
# <EpochsFIF | 510 events (all good), -0.2 – 1.5 s (baseline -0.2 – 0 s), ~82.3 MiB, data loaded,
#  'acordeón': 6
#  'ardilla': 6
#  'arpa ': 6
#  'awi': 4
#  'bacoli': 4
#  'banjo': 6
#  'batería': 6
#  'boina': 6
#  'boiri': 4
#  'bolso': 6
#  and 81 more events ...>

# %%
epochs = mne.read_epochs('/home/owaismujtaba/projects/IberSpeech2026/processed/words/sub-02_ses-1.fif')
# Out:
# Reading /home/owaismujtaba/projects/IberSpeech2026/processed/words/sub-02_ses-1.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 510 matching events found
# No baseline correction applied
# 0 projection items activated
# /tmp/ipykernel_287069/2866890785.py:1: RuntimeWarning: This filename (/home/owaismujtaba/projects/IberSpeech2026/processed/words/sub-02_ses-1.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs('/home/owaismujtaba/projects/IberSpeech2026/processed/words/sub-02_ses-1.fif')

# %%
epochs.annotations[0]
# Out:
# OrderedDict([('onset', np.float64(25.881999969482422)),
#              ('duration', np.float64(0.0)),
#              ('description',
#               np.str_('SilentSyllablesPracticeStartFixation:Audio_silence')),
#              ('orig_time',
#               datetime.datetime(2024, 7, 10, 8, 39, 39, tzinfo=datetime.timezone.utc)),
#              ('extras', {})])

# %%
epochs.event_id
# Out:
# {'acordeón': 9694,
#  'ardilla': 6707,
#  'arpa ': 5661,
#  'awi': 6248,
#  'bacoli': 9659,
#  'banjo': 2978,
#  'batería': 6625,
#  'boina': 9511,
#  'boiri': 8216,
#  'bolso': 9493,
#  'brócoli': 6862,
#  'bucor': 6286,
#  'bufanda': 9584,
#  'bíceps': 3525,
#  'búho': 724,
#  'caballo': 6564,
#  'cambopla': 6238,
#  'camiseta': 8776,
#  'campana': 801,
#  'cebolla ': 1468,
#  'celafo': 6501,
#  'cinriz': 8025,
#  'cinturón': 4559,
#  'cladi': 3256,
#  'clarinete': 8801,
#  'colador': 1925,
#  'coliflor': 4584,
#  'cucharón': 4164,
#  'cuchillo': 2140,
#  'cuterrino': 9132,
#  'embudo ': 1587,
#  'empe': 780,
#  'esmi': 9306,
#  'espátula': 7067,
#  'foca': 1374,
#  'galleta': 4384,
#  'gato': 3475,
#  'gatulón': 3342,
#  'guidía': 8025,
#  'guitarra': 8266,
#  'hiena': 7746,
#  'hombro': 7705,
#  'hompirra': 2065,
#  'kimado': 4391,
#  'kiwi ': 2584,
#  'lesorón': 7700,
#  'león': 4835,
#  'loro': 5984,
#  'loñiría': 8650,
#  'mancrose': 9357,
#  'manopla': 7932,
# ...

# %%
for
